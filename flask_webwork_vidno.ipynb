# %%
import os 
import sys
from flask import Flask, request, redirect, url_for, render_template
from werkzeug.utils import secure_filename
import face_recognition
import cv2
import numpy as np

UPLOAD_FOLDER = 'upload/'
ALLOWED_EXTENSIONS = set(['txt','mp4'])
app = Flask(__name__)
app.config['UPLOAD_FOLDER'] = UPLOAD_FOLDER

def allowed_file(filename):
    return '.' in filename and \
           filename.rsplit('.', 1)[1] in ALLOWED_EXTENSIONS

@app.route("/", methods=['GET', 'POST'])
#app.add_url_rule('/', methods = ['GET','POST'])
def index():
    if request.method == 'POST':
        file = request.files['file']
        if file and allowed_file(file.filename):
            filename = secure_filename(file.filename)
            file.save(os.path.join(app.config['UPLOAD_FOLDER'], filename))
            NEWPATH=videotest(os.path.join(app.config['UPLOAD_FOLDER'], filename))
            return render_template('video.html')
        
    return """
    <!doctype html>
    <title>Upload new File</title>
    <h1>Upload new File</h1>
    <form action="" method=post enctype=multipart/form-data>
      <p><input type=file name=file>
         <input type=submit value=Upload>
    </form>
    <p>%s</p>
    """ % "<br>".join(os.listdir(app.config['UPLOAD_FOLDER'],))



def videotest(filename):
    video_capture = cv2.VideoCapture(filename)
    length = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = int(video_capture.get(cv2.CAP_PROP_FPS))

    person1 = face_recognition.load_image_file("person1.png")
    hfencoding = face_recognition.face_encodings(person1)[0]

    person2 = face_recognition.load_image_file("person2.png")
    pfencoding = face_recognition.face_encodings(person2)[0]

   
    known_face_encodings = [
        hfencoding,
        pfencoding
    ]
    known_face_names = [
        "Person1",
        "Person2"
    ]

    width  = int(video_capture.get(3)) # float
    height = int(video_capture.get(4))
    
    fourcc = cv2.VideoWriter_fourcc(*'vp80')
    PATH = 'static/demo.webm'
    out = cv2.VideoWriter(PATH,fourcc, fps, (width,height))
    for i in range(1,length-1):
        
        ret, frame = video_capture.read()
        rgb_frame = frame[:, :, ::-1]
        face_locations = face_recognition.face_locations(rgb_frame)
        face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)

        for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
            matches = face_recognition.compare_faces(known_face_encodings, face_encoding)
            name = "Unknown"
            face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
            best_match_index = np.argmin(face_distances)
            if matches[best_match_index]:
                name = known_face_names[best_match_index]

            cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)
            cv2.rectangle(frame, (left, bottom - 10), (right, bottom + 10 ), (10, 10, 10), cv2.FILLED)
            font = cv2.FONT_HERSHEY_DUPLEX
            cv2.putText(frame, name, (left + 2, bottom), font, 0.4, (255, 255, 255), 1)

        print()
        sys.stdout.write(f"writing...{int((i/length)*100)+1}%")
        sys.stdout.flush()
        out.write(frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    video_capture.release()
    out.release()
    cv2.destroyAllWindows()
    return PATH

    
if __name__ == "__main__":
    app.run(host='127.0.0.1', port=5005, debug=False)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5005/ (Press CTRL+C to quit)
# 127.0.0.1 - - [08/Jan/2021 12:08:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Jan/2021 12:08:26] "GET /favicon.ico HTTP/1.1" 404 -
# writing...1%
# writing...2%
# writing...2%
# writing...3%
# writing...3%
# writing...4%
# writing...5%
# writing...5%
# writing...6%
# writing...6%
# writing...7%
# writing...7%
# writing...8%
# writing...9%
# writing...9%
# writing...10%
# writing...10%
# writing...11%
# writing...12%
# writing...12%
# writing...13%
# writing...13%
# writing...14%
# writing...14%
# writing...15%
# writing...16%
# writing...16%
# writing...17%
# writing...17%
# writing...18%
# writing...19%
# writing...19%
# writing...20%
# writing...20%
# writing...21%
# writing...21%
# writing...22%
# writing...23%
# writing...23%
# writing...24%
# writing...24%
# writing...25%
# writing...26%
# writing...26%
# writing...27%
# writing...27%
# writing...28%
# writing...28%
# writing...29%
# writing...30%
# writing...30%
# writing...31%
# writing...31%
# writing...32%
# writing...32%
# writing...33%
# writing...34%
# writing...34%
# writing...35%
# writing...35%
# writing...36%
# writing...37%
# writing...37%
# writing...38%
# writing...38%
# writing...39%
# writing...39%
# writing...40%
# writing...41%
# writing...41%
# writing...42%
# writing...42%
# writing...43%
# writing...44%
# writing...44%
# writing...45%
# writing...45%
# writing...46%
# writing...46%
# writing...47%
# writing...48%
# writing...48%
# writing...49%
# writing...49%
# writing...50%
# writing...51%
# writing...51%
# writing...52%
# writing...52%
# writing...53%
# writing...53%
# writing...54%
# writing...55%
# writing...55%
# writing...56%
# writing...56%
# writing...57%
# writing...57%
# writing...58%
# writing...59%
# writing...59%
# writing...60%
# writing...60%
# writing...61%
# writing...62%
# writing...62%
# writing...63%
# writing...63%
# writing...64%
# writing...64%
# writing...65%
# writing...66%
# writing...66%
# writing...67%
# writing...67%
# writing...68%
# writing...69%
# writing...69%
# writing...70%
# writing...70%
# writing...71%
# writing...71%
# writing...72%
# writing...73%
# writing...73%
# writing...74%
# writing...74%
# writing...75%
# writing...76%
# writing...76%
# writing...77%
# writing...77%
# writing...78%
# writing...78%
# writing...79%
# writing...80%
# writing...80%
# writing...81%
# writing...81%
# writing...82%
# writing...82%
# writing...83%
# writing...84%
# writing...84%
# writing...85%
# writing...85%
# writing...86%
# writing...87%
# writing...87%
# writing...88%
# writing...88%
# writing...89%
# writing...89%
# writing...90%
# writing...91%
# writing...91%
# writing...92%
# writing...92%
# writing...93%
# writing...94%
# writing...94%
# writing...95%
# writing...95%
# writing...96%
# writing...96%
# writing...97%
# writing...98%
# writing...98%
# writing...99%
# writing...99%
# 127.0.0.1 - - [08/Jan/2021 12:11:55] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Jan/2021 12:12:06] "GET /static/demo.webm HTTP/1.1" 206 -
# 127.0.0.1 - - [08/Jan/2021 12:12:07] "GET /static/demo.webm HTTP/1.1" 206 -
# 127.0.0.1 - - [08/Jan/2021 12:12:07] "GET /static/demo.webm HTTP/1.1" 206 -
# 127.0.0.1 - - [08/Jan/2021 12:12:07] "GET /static/demo.webm HTTP/1.1" 206 -
# 127.0.0.1 - - [08/Jan/2021 12:12:07] "GET /static/demo.webm HTTP/1.1" 206 -
# 127.0.0.1 - - [08/Jan/2021 12:12:07] "GET /static/demo.webm HTTP/1.1" 206 -
# 127.0.0.1 - - [08/Jan/2021 12:12:07] "GET /static/demo.webm HTTP/1.1" 206 -
# 127.0.0.1 - - [08/Jan/2021 12:12:07] "GET /static/demo.webm HTTP/1.1" 206 -
# 127.0.0.1 - - [08/Jan/2021 12:12:07] "GET /static/demo.webm HTTP/1.1" 206 -
# 127.0.0.1 - - [08/Jan/2021 12:12:07] "GET /static/demo.webm HTTP/1.1" 206 -
# 127.0.0.1 - - [08/Jan/2021 12:12:07] "GET /static/demo.webm HTTP/1.1" 206 -
# 127.0.0.1 - - [08/Jan/2021 12:12:07] "GET /static/demo.webm HTTP/1.1" 206 -
# 127.0.0.1 - - [08/Jan/2021 12:12:08] "GET /static/demo.webm HTTP/1.1" 206 -
# 127.0.0.1 - - [08/Jan/2021 12:12:11] "GET /static/demo.webm HTTP/1.1" 206 -

# %%
# Out:
#   File "<ipython-input-5-21bccc6d46a7>", line 5
#     @app.route("/", methods=['GET', 'POST'])
#                                             ^
# SyntaxError: unexpected EOF while parsing
